# %%
import pandas as pd
import numpy as np

# %%
project_dir = '~/RL_2024/'

# %%
df_train = pd.read_csv(project_dir + 'data/traj_data_train.csv')
df_val = pd.read_csv(project_dir + './data/traj_data_val.csv')
df_test = pd.read_csv(project_dir + './data/traj_data_test.csv')

# %%
df_train[['traj', 'm:icustayid']].astype(int).drop_duplicates().to_csv(project_dir + 'data/icustayid_train.csv', index=False)
df_val[['traj', 'm:icustayid']].astype(int).drop_duplicates().to_csv(project_dir + 'data/icustayid_val.csv', index=False)
df_test[['traj', 'm:icustayid']].astype(int).drop_duplicates().to_csv(project_dir + 'data/icustayid_test.csv', index=False)

# %%
df = pd.read_csv('~/RL_2024/dataset/sepsis_final_data_withTimes_newActions.csv')

# %%
df
# Out:
#          traj  step  m:presumed_onset   m:charttime  m:icustayid  o:gender  \
# 0           1     0      7.245590e+09  7.245486e+09     200003.0      -0.5
# 1           1     1      7.245590e+09  7.245500e+09     200003.0      -0.5
# 2           1     2      7.245590e+09  7.245515e+09     200003.0      -0.5
# 3           1     3      7.245590e+09  7.245529e+09     200003.0      -0.5
# 4           1     4      7.245590e+09  7.245544e+09     200003.0      -0.5
# ...       ...   ...               ...           ...          ...       ...
# 256568  19626     8      4.612800e+09  4.612888e+09     299995.0      -0.5
# 256569  19626     9      4.612800e+09  4.612903e+09     299995.0      -0.5
# 256570  19626    10      4.612800e+09  4.612917e+09     299995.0      -0.5
# 256571  19626    11      4.612800e+09  4.612932e+09     299995.0      -0.5
# 256572  19626    12      4.612800e+09  4.612946e+09     299995.0      -0.5
#
#         o:mechvent  o:re_admission     o:age  o:Weight_kg  ...  \
# ...

# %%
df.columns
# Out:
# Index(['traj', 'step', 'm:presumed_onset', 'm:charttime', 'm:icustayid',
#        'o:gender', 'o:mechvent', 'o:re_admission', 'o:age', 'o:Weight_kg',
#        'o:GCS', 'o:HR', 'o:SysBP', 'o:MeanBP', 'o:DiaBP', 'o:RR', 'o:Temp_C',
#        'o:FiO2_1', 'o:Potassium', 'o:Sodium', 'o:Chloride', 'o:Glucose',
#        'o:Magnesium', 'o:Calcium', 'o:Hb', 'o:WBC_count', 'o:Platelets_count',
#        'o:PTT', 'o:PT', 'o:Arterial_pH', 'o:paO2', 'o:paCO2', 'o:Arterial_BE',
#        'o:HCO3', 'o:Arterial_lactate', 'o:SOFA', 'o:SIRS', 'o:Shock_Index',
#        'o:PaO2_FiO2', 'o:cumulated_balance', 'o:SpO2', 'o:BUN', 'o:Creatinine',
#        'o:SGOT', 'o:SGPT', 'o:Total_bili', 'o:INR', 'o:input_total',
#        'o:output_total', 'o:output_4hourly', 'r:reward', 'o:max_dose_vaso',
#        'o:input_4hourly', 'a:vaso', 'a:iv_OLD', 'a:iv', 'a:action_OLD',
#        'a:action'],
#       dtype='object')

# %%
df[df['traj'] == 1]
# Out:
#    traj  step  m:presumed_onset   m:charttime  m:icustayid  o:gender  \
# 0     1     0      7.245590e+09  7.245486e+09     200003.0      -0.5
# 1     1     1      7.245590e+09  7.245500e+09     200003.0      -0.5
# 2     1     2      7.245590e+09  7.245515e+09     200003.0      -0.5
# 3     1     3      7.245590e+09  7.245529e+09     200003.0      -0.5
# 4     1     4      7.245590e+09  7.245544e+09     200003.0      -0.5
# 5     1     5      7.245590e+09  7.245558e+09     200003.0      -0.5
# 6     1     6      7.245590e+09  7.245601e+09     200003.0      -0.5
#
#    o:mechvent  o:re_admission     o:age  o:Weight_kg  ...  o:output_total  \
# 0        -0.5            -0.5 -0.975759    -0.178920  ...        0.778741
# 1        -0.5            -0.5 -0.975759    -0.178920  ...        0.786546
# 2        -0.5            -0.5 -0.975759    -0.178920  ...        0.792397
# 3        -0.5            -0.5 -0.975759    -0.145806  ...        0.799349
# ...
